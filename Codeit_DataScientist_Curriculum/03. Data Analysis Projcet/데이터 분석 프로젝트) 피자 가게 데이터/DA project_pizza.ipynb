# %% [markdown]
# ### 데이터 전처리 및 탐색

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
orders_df = pd.read_csv('data/orders.csv')
orders_df.head(10)
# Out:
#    order_id      order_timestamp  order_details_id         pizza_id  quantity
# 0         1  2023-01-01 11:45:11                 1       hawaiian_m         1
# 1         2  2023-01-01 11:53:26                 2       big_meat_l         1
# 2         2  2023-01-01 11:53:26                 3    classic_dlx_m         1
# 3         2  2023-01-01 11:53:26                 4    five_cheese_l         1
# 4         2  2023-01-01 11:53:26                 5         potato_m         1
# 5         2  2023-01-01 11:53:26                 6       thai_ckn_l         1
# 6         3  2023-01-01 11:54:22                 7      pepperoni_l         1
# 7         3  2023-01-01 11:54:22                 8  super_supreme_m         1
# 8         4  2023-01-01 12:09:18                 9       big_meat_m         1
# 9         5  2023-01-01 12:15:29                10  super_supreme_m         1

# %%
pizzas_df = pd.read_csv('data/pizzas.csv')
pizzas_df.head(10)
# Out:
#         pizza_id  pizza_name size  price
# 0      bbq_ckn_s   바비큐 치킨 피자    S  11300
# 1      bbq_ckn_m   바비큐 치킨 피자    M  22000
# 2      bbq_ckn_l   바비큐 치킨 피자    L  34000
# 3     thai_ckn_s    타이 치킨 피자    S  12300
# 4     thai_ckn_m    타이 치킨 피자    M  24000
# 5     thai_ckn_l    타이 치킨 피자    L  36800
# 6     big_meat_s     빅 미트 피자    S  11300
# 7     big_meat_m     빅 미트 피자    M  22000
# 8     big_meat_l     빅 미트 피자    L  34000
# 9  classic_dlx_s  클래식 디럭스 피자    S  10800

# %%
pizza_types_df = pd.read_csv('data/pizza_types.csv')
pizza_types_df.head()
# Out:
#    pizza_name category                      ingredients
# 0   바비큐 치킨 피자       치킨         치킨, 피망, 토마토, 적양파, 바비큐 소스
# 1    타이 치킨 피자       치킨      치킨, 파인애플, 토마토, 피망, 타이 칠리 소스
# 2     빅 미트 피자      클래식         베이컨, 토마토, 페퍼로니, 살라미, 초리조
# 3  클래식 디럭스 피자      클래식      토마토, 페퍼로니, 버섯, 적양파, 피망, 베이컨
# 4   슈퍼 슈프림 피자      클래식  페퍼로니, 토마토, 적양파, 그린 올리브, 옥수수, 마늘

# %%
merged_order_pizza = pd.merge(orders_df, pizzas_df, how='left', on='pizza_id')
merged_order_pizza.head()
# Out:
#    order_id      order_timestamp  order_details_id       pizza_id  quantity  \
# 0         1  2023-01-01 11:45:11                 1     hawaiian_m         1
# 1         2  2023-01-01 11:53:26                 2     big_meat_l         1
# 2         2  2023-01-01 11:53:26                 3  classic_dlx_m         1
# 3         2  2023-01-01 11:53:26                 4  five_cheese_l         1
# 4         2  2023-01-01 11:53:26                 5       potato_m         1
#
#    pizza_name size  price
# 0     하와이안 피자    M  21800
# 1     빅 미트 피자    L  34000
# 2  클래식 디럭스 피자    M  20300
# 3   파이브 치즈 피자    L  31000
# 4     포테이토 피자    M  21800

# %%
merged_order_pizza['total_price'] = merged_order_pizza['quantity'] * merged_order_pizza['price']
merged_order_pizza = merged_order_pizza.rename(columns={'price': 'unit_price'})
merged_order_pizza.head()
# Out:
#    order_id      order_timestamp  order_details_id       pizza_id  quantity  \
# 0         1  2023-01-01 11:45:11                 1     hawaiian_m         1
# 1         2  2023-01-01 11:53:26                 2     big_meat_l         1
# 2         2  2023-01-01 11:53:26                 3  classic_dlx_m         1
# 3         2  2023-01-01 11:53:26                 4  five_cheese_l         1
# 4         2  2023-01-01 11:53:26                 5       potato_m         1
#
#    pizza_name size  unit_price  total_price
# 0     하와이안 피자    M       21800        21800
# 1     빅 미트 피자    L       34000        34000
# 2  클래식 디럭스 피자    M       20300        20300
# 3   파이브 치즈 피자    L       31000        31000
# 4     포테이토 피자    M       21800        21800

# %%
pizza_orders_df = pd.merge(merged_order_pizza, pizza_types_df, how='left', on='pizza_name')
pizza_orders_df.head()
# Out:
#    order_id      order_timestamp  order_details_id       pizza_id  quantity  \
# 0         1  2023-01-01 11:45:11                 1     hawaiian_m         1
# 1         2  2023-01-01 11:53:26                 2     big_meat_l         1
# 2         2  2023-01-01 11:53:26                 3  classic_dlx_m         1
# 3         2  2023-01-01 11:53:26                 4  five_cheese_l         1
# 4         2  2023-01-01 11:53:26                 5       potato_m         1
#
#    pizza_name size  unit_price  total_price category  \
# 0     하와이안 피자    M       21800        21800      스페셜
# 1     빅 미트 피자    L       34000        34000      클래식
# 2  클래식 디럭스 피자    M       20300        20300      클래식
# 3   파이브 치즈 피자    L       31000        31000    베지테리언
# 4     포테이토 피자    M       21800        21800      스페셜
#
#                                    ingredients
# 0                      토마토, 베이컨, 파인애플, 모짜렐라 치즈
# 1                     베이컨, 토마토, 페퍼로니, 살라미, 초리조
# 2                  토마토, 페퍼로니, 버섯, 적양파, 피망, 베이컨
# 3  모짜렐라 치즈, 프로볼로네 치즈, 고다 치즈, 페코리노 치즈, 고르곤졸라 치즈
# 4         모짜렐라 치즈, 토마토, 감자, 양파, 베이컨, 옥수수, 마요네즈

# %%
pizza_orders_df.shape
# Out:
# (47079, 11)

# %%
pizza_orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47079 entries, 0 to 47078
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          47079 non-null  int64
#  1   order_timestamp   47079 non-null  object
#  2   order_details_id  47079 non-null  int64
#  3   pizza_id          47079 non-null  object
#  4   quantity          47079 non-null  int64
#  5   pizza_name        47079 non-null  object
#  6   size              47079 non-null  object
#  7   unit_price        47079 non-null  int64
#  8   total_price       47079 non-null  int64
#  9   category          47079 non-null  object
#  10  ingredients       47079 non-null  object
# dtypes: int64(5), object(6)
# memory usage: 4.0+ MB

# %%
pizza_orders_df.describe(include='all')
# Out:
#             order_id      order_timestamp  order_details_id    pizza_id  \
# count   47079.000000                47079      47079.000000       47079
# unique           NaN                21350               NaN          39
# top              NaN  2023-11-18 21:10:53               NaN  thai_ckn_l
# freq             NaN                   19               NaN        2495
# mean    10708.712058                  NaN      23540.000000         NaN
# std      6175.450615                  NaN      13590.680998         NaN
# min         1.000000                  NaN          1.000000         NaN
# 25%      5352.500000                  NaN      11770.500000         NaN
# 50%     10696.000000                  NaN      23540.000000         NaN
# 75%     16100.500000                  NaN      35309.500000         NaN
# max     21350.000000                  NaN      47079.000000         NaN
#
#             quantity pizza_name   size    unit_price    total_price category  \
# count   47079.000000      47079  47079  47079.000000   47079.000000    47079
# unique           NaN         13      3           NaN            NaN        4
# top              NaN    하와이안 피자      L           NaN            NaN      클래식
# freq             NaN       5909  18378           NaN            NaN    17437
# mean        1.052996        NaN    NaN  22945.597825   24233.356698      NaN
# std         0.242338        NaN    NaN   9376.523771   11887.470629      NaN
# min         1.000000        NaN    NaN   9300.000000    9300.000000      NaN
# 25%         1.000000        NaN    NaN  11300.000000   12300.000000      NaN
# 50%         1.000000        NaN    NaN  21800.000000   22000.000000      NaN
# 75%         1.000000        NaN    NaN  32300.000000   33800.000000      NaN
# max         5.000000        NaN    NaN  38800.000000  169000.000000      NaN
#
#                     ingredients
# count                     47079
# unique                       13
# top     토마토, 베이컨, 파인애플, 모짜렐라 치즈
# freq                       5909
# mean                        NaN
# std                         NaN
# min                         NaN
# 25%                         NaN
# 50%                         NaN
# 75%                         NaN
# max                         NaN

# %%
print(pizza_orders_df['pizza_name'].unique())
print(pizza_orders_df['size'].unique())
print(pizza_orders_df['category'].unique())
# Out:
# ['하와이안 피자' '빅 미트 피자' '클래식 디럭스 피자' '파이브 치즈 피자' '포테이토 피자' '타이 치킨 피자'
#  '페퍼로니 피자' '슈퍼 슈프림 피자' '바비큐 치킨 피자' '프로슈토 루꼴라 피자' '그린 가든 피자' '시금치 페스토 피자'
#  '불고기 피자']
# ['M' 'L' 'S']
# ['스페셜' '클래식' '베지테리언' '치킨']

# %%
pizza_orders_df['order_timestamp'] = pd.to_datetime(pizza_orders_df['order_timestamp'])
pizza_orders_df['order_timestamp'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 47079 entries, 0 to 47078
# Series name: order_timestamp
# Non-Null Count  Dtype
# --------------  -----
# 47079 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 367.9 KB

# %%
print('첫 주문 일시:', pizza_orders_df['order_timestamp'].min())
print('마지막 주문 일시:', pizza_orders_df['order_timestamp'].max())
# Out:
# 첫 주문 일시: 2023-01-01 11:45:11
# 마지막 주문 일시: 2023-12-31 21:56:56

# %% [markdown]
# ### 매장 분석 I : 종합 결산

# %%
total_days = pizza_orders_df['order_timestamp'].dt.date.nunique()
print(f'영업일 수: {total_days}일')
# Out:
# 영업일 수: 358일

# %%
total_sales = pizza_orders_df['total_price'].sum()
print(f'총매출: {total_sales:,.0f}원')
# Out:
# 총매출: 1,140,882,200원

# %%
sales_per_day = total_sales / total_days
print(f'하루 평균 매출: {sales_per_day:,.0f}원')
# Out:
# 하루 평균 매출: 3,186,822원

# %%
total_orders = pizza_orders_df['order_id'].nunique()
print(f'주문 횟수: {total_orders:,.0f}회')
# Out:
# 주문 횟수: 21,350회

# %%
avg_purchase_price = total_sales / total_orders
print(f'평균 주문 금액: {avg_purchase_price:,.0f}원')
# Out:
# 평균 주문 금액: 53,437원

# %%
total_quantity = pizza_orders_df['quantity'].sum()
print(f'총판매량: {total_quantity:,.0f}판')
# Out:
# 총판매량: 49,574판

# %%
quantity_per_order = pizza_orders_df.groupby('order_id')['quantity'].sum()
quantity_per_order = quantity_per_order.sort_values(ascending=False)
quantity_per_order.head()
# Out:
# order_id
# 18845    28
# 10760    25
# 18513    15
# 21158    15
# 20163    15
# Name: quantity, dtype: int64

# %%
pizza_orders_df[pizza_orders_df['order_id'] == 18845]
# Out:
#        order_id     order_timestamp  order_details_id         pizza_id  \
# 41491     18845 2023-11-18 21:10:53             41492        bbq_ckn_m
# 41492     18845 2023-11-18 21:10:53             41493       big_meat_l
# 41493     18845 2023-11-18 21:10:53             41494       big_meat_s
# 41494     18845 2023-11-18 21:10:53             41495        bulgogi_l
# 41495     18845 2023-11-18 21:10:53             41496    classic_dlx_m
# 41496     18845 2023-11-18 21:10:53             41497    classic_dlx_s
# 41497     18845 2023-11-18 21:10:53             41498   green_garden_m
# 41498     18845 2023-11-18 21:10:53             41499       hawaiian_l
# 41499     18845 2023-11-18 21:10:53             41500       hawaiian_m
# 41500     18845 2023-11-18 21:10:53             41501       hawaiian_s
# 41501     18845 2023-11-18 21:10:53             41502      pepperoni_m
# 41502     18845 2023-11-18 21:10:53             41503      pepperoni_s
# 41503     18845 2023-11-18 21:10:53             41504         potato_l
# 41504     18845 2023-11-18 21:10:53             41505         potato_m
# 41505     18845 2023-11-18 21:10:53             41506     spin_pesto_s
# 41506     18845 2023-11-18 21:10:53             41507  super_supreme_l
# 41507     18845 2023-11-18 21:10:53             41508  super_supreme_s
# 41508     18845 2023-11-18 21:10:53             41509       thai_ckn_l
# 41509     18845 2023-11-18 21:10:53             41510       thai_ckn_m
#
#        quantity  pizza_name size  unit_price  total_price category  \
# 41491         3   바비큐 치킨 피자    M       22000        66000       치킨
# 41492         1     빅 미트 피자    L       34000        34000      클래식
# 41493         2     빅 미트 피자    S       11300        22600      클래식
# 41494         1      불고기 피자    L       32300        32300      스페셜
# 41495         1  클래식 디럭스 피자    M       20300        20300      클래식
# 41496         1  클래식 디럭스 피자    S       10800        10800      클래식
# 41497         1    그린 가든 피자    M       21800        21800    베지테리언
# 41498         2     하와이안 피자    L       33800        67600      스페셜
# 41499         2     하와이안 피자    M       21800        43600      스페셜
# 41500         2     하와이안 피자    S       11000        22000      스페셜
# 41501         3     페퍼로니 피자    M       18300        54900      클래식
# 41502         1     페퍼로니 피자    S        9300         9300      클래식
# 41503         1     포테이토 피자    L       33800        33800      스페셜
# 41504         1     포테이토 피자    M       21800        21800      스페셜
# 41505         1  시금치 페스토 피자    S       13800        13800    베지테리언
# 41506         1   슈퍼 슈프림 피자    L       32300        32300      클래식
# 41507         1   슈퍼 슈프림 피자    S       10800        10800      클래식
# 41508         2    타이 치킨 피자    L       36800        73600       치킨
# 41509         1    타이 치킨 피자    M       24000        24000       치킨
#
#                                 ingredients
# 41491              치킨, 피망, 토마토, 적양파, 바비큐 소스
# 41492              베이컨, 토마토, 페퍼로니, 살라미, 초리조
# 41493              베이컨, 토마토, 페퍼로니, 살라미, 초리조
# 41494      불고기, 불고기 소스, 버섯, 양파, 피망, 모짜렐라 치즈
# 41495           토마토, 페퍼로니, 버섯, 적양파, 피망, 베이컨
# 41496           토마토, 페퍼로니, 버섯, 적양파, 피망, 베이컨
# 41497    가지, 아티초크, 토마토, 쥬키니, 피망, 마늘, 페스토 소스
# 41498               토마토, 베이컨, 파인애플, 모짜렐라 치즈
# 41499               토마토, 베이컨, 파인애플, 모짜렐라 치즈
# 41500               토마토, 베이컨, 파인애플, 모짜렐라 치즈
# 41501                    토마토, 모짜렐라 치즈, 페퍼로니
# 41502                    토마토, 모짜렐라 치즈, 페퍼로니
# 41503  모짜렐라 치즈, 토마토, 감자, 양파, 베이컨, 옥수수, 마요네즈
# 41504  모짜렐라 치즈, 토마토, 감자, 양파, 베이컨, 옥수수, 마요네즈
# 41505  시금치, 아티초크, 토마토, 썬드라이 토마토, 마늘, 페스토 소스
# 41506       페퍼로니, 토마토, 적양파, 그린 올리브, 옥수수, 마늘
# 41507       페퍼로니, 토마토, 적양파, 그린 올리브, 옥수수, 마늘
# 41508           치킨, 파인애플, 토마토, 피망, 타이 칠리 소스
# 41509           치킨, 파인애플, 토마토, 피망, 타이 칠리 소스

# %%
plt.rc('font', family='Malgun Gothic')

# %%
pizza_orders_df['month'] = pizza_orders_df['order_timestamp'].dt.month
pizza_orders_df.head()
# Out:
#    order_id     order_timestamp  order_details_id       pizza_id  quantity  \
# 0         1 2023-01-01 11:45:11                 1     hawaiian_m         1
# 1         2 2023-01-01 11:53:26                 2     big_meat_l         1
# 2         2 2023-01-01 11:53:26                 3  classic_dlx_m         1
# 3         2 2023-01-01 11:53:26                 4  five_cheese_l         1
# 4         2 2023-01-01 11:53:26                 5       potato_m         1
#
#    pizza_name size  unit_price  total_price category  \
# 0     하와이안 피자    M       21800        21800      스페셜
# 1     빅 미트 피자    L       34000        34000      클래식
# 2  클래식 디럭스 피자    M       20300        20300      클래식
# 3   파이브 치즈 피자    L       31000        31000    베지테리언
# 4     포테이토 피자    M       21800        21800      스페셜
#
#                                    ingredients  month
# 0                      토마토, 베이컨, 파인애플, 모짜렐라 치즈      1
# 1                     베이컨, 토마토, 페퍼로니, 살라미, 초리조      1
# 2                  토마토, 페퍼로니, 버섯, 적양파, 피망, 베이컨      1
# 3  모짜렐라 치즈, 프로볼로네 치즈, 고다 치즈, 페코리노 치즈, 고르곤졸라 치즈      1
# 4         모짜렐라 치즈, 토마토, 감자, 양파, 베이컨, 옥수수, 마요네즈      1

# %%
sales_by_month = pizza_orders_df.groupby('month')['total_price'].sum().reset_index()
sales_by_month
# Out:
#     month  total_price
# 0       1     93718700
# 1       2     89392300
# 2       3     98494600
# 3       4     96277400
# 4       5    100225300
# 5       6     95518100
# 6       7    101553600
# 7       8     94873600
# 8       9     89302500
# 9      10     88423800
# 10     11     97437500
# 11     12     95664800

# %%
plt.rcParams['figure.figsize'] = (10, 5)
sns.barplot(data=sales_by_month, x='month', y='total_price')
plt.title('월별 매출')
plt.xlabel('월')
plt.ylabel('매출(만 원)')
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{x/10000:,.0f}'))
plt.show()

# %%
pizza_orders_df['day'] = pizza_orders_df['order_timestamp'].dt.dayofweek
pizza_orders_df.head()
# Out:
#    order_id     order_timestamp  order_details_id       pizza_id  quantity  \
# 0         1 2023-01-01 11:45:11                 1     hawaiian_m         1
# 1         2 2023-01-01 11:53:26                 2     big_meat_l         1
# 2         2 2023-01-01 11:53:26                 3  classic_dlx_m         1
# 3         2 2023-01-01 11:53:26                 4  five_cheese_l         1
# 4         2 2023-01-01 11:53:26                 5       potato_m         1
#
#    pizza_name size  unit_price  total_price category  \
# 0     하와이안 피자    M       21800        21800      스페셜
# 1     빅 미트 피자    L       34000        34000      클래식
# 2  클래식 디럭스 피자    M       20300        20300      클래식
# 3   파이브 치즈 피자    L       31000        31000    베지테리언
# 4     포테이토 피자    M       21800        21800      스페셜
#
#                                    ingredients  month  day
# 0                      토마토, 베이컨, 파인애플, 모짜렐라 치즈      1    6
# 1                     베이컨, 토마토, 페퍼로니, 살라미, 초리조      1    6
# 2                  토마토, 페퍼로니, 버섯, 적양파, 피망, 베이컨      1    6
# 3  모짜렐라 치즈, 프로볼로네 치즈, 고다 치즈, 페코리노 치즈, 고르곤졸라 치즈      1    6
# 4         모짜렐라 치즈, 토마토, 감자, 양파, 베이컨, 옥수수, 마요네즈      1    6

# %%
sales_by_day = pizza_orders_df.groupby('day')['total_price'].sum().reset_index()
sales_by_day
# Out:
#    day  total_price
# 0    0    147541300
# 1    1    160866900
# 2    2    165848400
# 3    3    168921600
# 4    4    185106800
# 5    5    169516300
# 6    6    143080900

# %%
day_names = ['월', '화', '수', '목', '금', '토', '일']
plt.rcParams['figure.figsize'] = (10, 5)
sns.barplot(data=sales_by_day, x=day_names, y='total_price')
plt.title('요일별 매출')
plt.xlabel('요일')
plt.ylabel('매출(만 원)')
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{x/10000:,.0f}'))
plt.show()

# %%
pizza_orders_df['hour'] = pizza_orders_df['order_timestamp'].dt.hour
pizza_orders_df.head()
# Out:
#    order_id     order_timestamp  order_details_id       pizza_id  quantity  \
# 0         1 2023-01-01 11:45:11                 1     hawaiian_m         1
# 1         2 2023-01-01 11:53:26                 2     big_meat_l         1
# 2         2 2023-01-01 11:53:26                 3  classic_dlx_m         1
# 3         2 2023-01-01 11:53:26                 4  five_cheese_l         1
# 4         2 2023-01-01 11:53:26                 5       potato_m         1
#
#    pizza_name size  unit_price  total_price category  \
# 0     하와이안 피자    M       21800        21800      스페셜
# 1     빅 미트 피자    L       34000        34000      클래식
# 2  클래식 디럭스 피자    M       20300        20300      클래식
# 3   파이브 치즈 피자    L       31000        31000    베지테리언
# 4     포테이토 피자    M       21800        21800      스페셜
#
#                                    ingredients  month  day  hour
# 0                      토마토, 베이컨, 파인애플, 모짜렐라 치즈      1    6    11
# 1                     베이컨, 토마토, 페퍼로니, 살라미, 초리조      1    6    11
# 2                  토마토, 페퍼로니, 버섯, 적양파, 피망, 베이컨      1    6    11
# 3  모짜렐라 치즈, 프로볼로네 치즈, 고다 치즈, 페코리노 치즈, 고르곤졸라 치즈      1    6    11
# 4         모짜렐라 치즈, 토마토, 감자, 양파, 베이컨, 옥수수, 마요네즈      1    6    11

# %%
sales_by_hour = pizza_orders_df.groupby('hour')['total_price'].sum().reset_index()
sales_by_hour
# Out:
#     hour  total_price
# 0     10       461000
# 1     11     64896300
# 2     12    131185900
# 3     13    140566100
# 4     14     82838800
# 5     15     81688100
# 6     16    106494800
# 7     17    122837100
# 8     18    124612100
# 9     19    102778400
# 10    20     85177600
# 11    21     61476200
# 12    22     34003500
# 13    23      1866300

# %%
plt.rcParams['figure.figsize'] = (10, 5)
sns.barplot(data=sales_by_hour, x='hour', y='total_price')
plt.title('시간대별 매출')
plt.xlabel('시간대')
plt.ylabel('매출(만 원)')
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{x/10000:,.0f}'))

# %%
pizza_orders_df['type_of_day'] = pizza_orders_df['day'].apply(lambda x: '휴일' if x >= 5 else '평일')
pizza_orders_df.head()
# Out:
#    order_id     order_timestamp  order_details_id       pizza_id  quantity  \
# 0         1 2023-01-01 11:45:11                 1     hawaiian_m         1
# 1         2 2023-01-01 11:53:26                 2     big_meat_l         1
# 2         2 2023-01-01 11:53:26                 3  classic_dlx_m         1
# 3         2 2023-01-01 11:53:26                 4  five_cheese_l         1
# 4         2 2023-01-01 11:53:26                 5       potato_m         1
#
#    pizza_name size  unit_price  total_price category  \
# 0     하와이안 피자    M       21800        21800      스페셜
# 1     빅 미트 피자    L       34000        34000      클래식
# 2  클래식 디럭스 피자    M       20300        20300      클래식
# 3   파이브 치즈 피자    L       31000        31000    베지테리언
# 4     포테이토 피자    M       21800        21800      스페셜
#
#                                    ingredients  month  day  hour type_of_day
# 0                      토마토, 베이컨, 파인애플, 모짜렐라 치즈      1    6    11          휴일
# 1                     베이컨, 토마토, 페퍼로니, 살라미, 초리조      1    6    11          휴일
# 2                  토마토, 페퍼로니, 버섯, 적양파, 피망, 베이컨      1    6    11          휴일
# 3  모짜렐라 치즈, 프로볼로네 치즈, 고다 치즈, 페코리노 치즈, 고르곤졸라 치즈      1    6    11          휴일
# 4         모짜렐라 치즈, 토마토, 감자, 양파, 베이컨, 옥수수, 마요네즈      1    6    11          휴일

# %%
sales_by_day_hour = pizza_orders_df.groupby(['type_of_day', 'hour'])['total_price'].sum().reset_index()
sales_by_day_hour
# Out:
#    type_of_day  hour  total_price
# 0           평일    10       360100
# 1           평일    11     53667500
# 2           평일    12    108928000
# 3           평일    13    112149900
# 4           평일    14     55954700
# 5           평일    15     55864800
# 6           평일    16     73311400
# 7           평일    17     88357300
# 8           평일    18     87425300
# 9           평일    19     69155400
# 10          평일    20     58380800
# 11          평일    21     41067300
# 12          평일    22     22768100
# 13          평일    23       894400
# 14          휴일    10       100900
# 15          휴일    11     11228800
# 16          휴일    12     22257900
# 17          휴일    13     28416200
# 18          휴일    14     26884100
# 19          휴일    15     25823300
# 20          휴일    16     33183400
# 21          휴일    17     34479800
# 22          휴일    18     37186800
# 23          휴일    19     33623000
# 24          휴일    20     26796800
# 25          휴일    21     20408900
# 26          휴일    22     11235400
# 27          휴일    23       971900

# %%
day_type = '평일' # '평일' 또는 '휴일'

plt.rcParams['figure.figsize'] = (10, 5)
target_data = sales_by_day_hour[sales_by_day_hour['type_of_day'] == day_type]
sns.barplot(data=target_data, x='hour', y='total_price')
plt.title(f'{day_type} 시간대별 매출')
plt.xlabel('시간대')
plt.ylabel('매출(만 원)')
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{x/10000:,.0f}'))
plt.show()

# %%
day_type = '휴일'

plt.rcParams['figure.figsize'] = (10, 5)
target_data = sales_by_day_hour[sales_by_day_hour['type_of_day'] == day_type]
sns.barplot(data=target_data, x='hour', y='total_price')
plt.title(f'{day_type} 시간대별 매출')
plt.xlabel('시간대')
plt.ylabel('매출(만 원)')
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{x/10000:,.0f}'))
plt.show()

# %% [markdown]
# ### 매장 분석 III : 메뉴에 따른 판매량

# %%
quantity_by_pizza = pizza_orders_df.groupby('pizza_name')['quantity'].sum().reset_index()
quantity_by_pizza = quantity_by_pizza.sort_values(by='quantity', ascending=False)
quantity_by_pizza
# Out:
#      pizza_name  quantity
# 12      하와이안 피자      6316
# 9       페퍼로니 피자      6291
# 7      타이 치킨 피자      5432
# 6    클래식 디럭스 피자      4691
# 3       빅 미트 피자      4145
# 1     바비큐 치킨 피자      4065
# 8     파이브 치즈 피자      3609
# 10      포테이토 피자      3291
# 4     슈퍼 슈프림 피자      3279
# 0      그린 가든 피자      2621
# 5    시금치 페스토 피자      2616
# 2        불고기 피자      2115
# 11  프로슈토 루꼴라 피자      1103

# %%
plt.rcParams['figure.figsize'] = (10, 6)
sns.barplot(data=quantity_by_pizza, x='quantity', y='pizza_name')
plt.title('피자 메뉴별 판매량')
plt.xlabel('판매량(판)')
plt.ylabel('피자')
plt.show()

# %%
quantity_by_pizza_and_month = pizza_orders_df.groupby(['pizza_name', 'month'])['quantity'].sum().reset_index()
quantity_by_pizza_and_month
# Out:
#     pizza_name  month  quantity
# 0     그린 가든 피자      1       222
# 1     그린 가든 피자      2       212
# 2     그린 가든 피자      3       267
# 3     그린 가든 피자      4       209
# 4     그린 가든 피자      5       233
# ..         ...    ...       ...
# 151    하와이안 피자      8       538
# 152    하와이안 피자      9       498
# 153    하와이안 피자     10       473
# 154    하와이안 피자     11       533
# 155    하와이안 피자     12       536
#
# [156 rows x 3 columns]

# %%
plt.rcParams['figure.figsize'] = (15, 9)
sns.lineplot(data=quantity_by_pizza_and_month, x='month', y='quantity', hue='pizza_name', style='pizza_name')
plt.title('각 메뉴의 월별 판매량')
plt.xlabel('월')
plt.ylabel('판매량(판)')
plt.show()

# %%
plt.rcParams['figure.figsize'] = (15, 9)
sns.lineplot(data=quantity_by_pizza_and_month, x='month', y='quantity', hue='pizza_name', style='pizza_name', palette='deep', linewidth=2.5)
plt.title('각 메뉴의 월별 판매량')
plt.xlabel('월')
plt.ylabel('판매량(판)')
plt.grid(True)
plt.legend(loc='upper left', bbox_to_anchor=(1.01, 1))
plt.show()

# %%
quantity_by_pizza_and_size = pizza_orders_df.groupby(['pizza_name', 'size'])['quantity'].sum().reset_index()
quantity_by_pizza_and_size
# Out:
#      pizza_name size  quantity
# 0      그린 가든 피자    L       746
# 1      그린 가든 피자    M       884
# 2      그린 가든 피자    S       991
# 3     바비큐 치킨 피자    L      1674
# 4     바비큐 치킨 피자    M      1528
# 5     바비큐 치킨 피자    S       863
# 6        불고기 피자    L       860
# 7        불고기 피자    M       691
# 8        불고기 피자    S       564
# 9       빅 미트 피자    L       905
# 10      빅 미트 피자    M       769
# 11      빅 미트 피자    S      2471
# 12    슈퍼 슈프림 피자    L      1336
# 13    슈퍼 슈프림 피자    M      1153
# 14    슈퍼 슈프림 피자    S       790
# 15   시금치 페스토 피자    L       972
# 16   시금치 페스토 피자    M       845
# 17   시금치 페스토 피자    S       799
# 18   클래식 디럭스 피자    L      1393
# 19   클래식 디럭스 피자    M      1959
# 20   클래식 디럭스 피자    S      1339
# 21     타이 치킨 피자    L      2684
# 22     타이 치킨 피자    M      1481
# 23     타이 치킨 피자    S      1267
# 24    파이브 치즈 피자    L      2299
# 25    파이브 치즈 피자    M       772
# 26    파이브 치즈 피자    S       538
# 27      페퍼로니 피자    L      2309
# 28      페퍼로니 피자    M      2229
# 29      페퍼로니 피자    S      1753
# 30      포테이토 피자    L      1372
# 31      포테이토 피자    M      1113
# 32      포테이토 피자    S       806
# 33  프로슈토 루꼴라 피자    L       433
# 34  프로슈토 루꼴라 피자    M       379
# 35  프로슈토 루꼴라 피자    S       291
# 36      하와이안 피자    L      2553
# 37      하와이안 피자    M      1832
# 38      하와이안 피자    S      1931

# %%
plt.rcParams['figure.figsize'] = (15, 5)
sns.barplot(data=quantity_by_pizza_and_size, x='pizza_name', y='quantity', hue='size')
plt.title('메뉴 및 사이즈에 따른 판매량')
plt.xticks(rotation=45)
plt.xlabel('피자')
plt.ylabel('판매량(판)')
plt.show()

# %% [markdown]
# ### 매장 분석 IV : 카테고리별 판매량

# %%
quantity_by_category = pizza_orders_df.groupby('category')['quantity'].sum().reset_index()
quantity_by_category
# Out:
#   category  quantity
# 0    베지테리언      8846
# 1      스페셜     12825
# 2       치킨      9497
# 3      클래식     18406

# %%
quantity_by_category_pizza = pizza_orders_df.groupby(['category', 'pizza_name'])['quantity'].sum().reset_index()
quantity_by_category_pizza
# Out:
#    category   pizza_name  quantity
# 0     베지테리언     그린 가든 피자      2621
# 1     베지테리언   시금치 페스토 피자      2616
# 2     베지테리언    파이브 치즈 피자      3609
# 3       스페셜       불고기 피자      2115
# 4       스페셜      포테이토 피자      3291
# 5       스페셜  프로슈토 루꼴라 피자      1103
# 6       스페셜      하와이안 피자      6316
# 7        치킨    바비큐 치킨 피자      4065
# 8        치킨     타이 치킨 피자      5432
# 9       클래식      빅 미트 피자      4145
# 10      클래식    슈퍼 슈프림 피자      3279
# 11      클래식   클래식 디럭스 피자      4691
# 12      클래식      페퍼로니 피자      6291

# %%
plt.figure(figsize=(10, 5))
sns.barplot(data=quantity_by_category_pizza, x='pizza_name', y='quantity', hue='category')
plt.title('카테고리와 메뉴에 따른 판매량')
plt.xticks(rotation=45)
plt.xlabel('피자')
plt.ylabel('판매량(판)')
plt.show()

# %% [markdown]
# ### 매장 분석 V : 재료 사용량

# %%
pizza_orders_df['ingredients_handled'] = pizza_orders_df['ingredients'].str.split(', ')
pizza_orders_df.head()
# Out:
#    order_id     order_timestamp  order_details_id       pizza_id  quantity  \
# 0         1 2023-01-01 11:45:11                 1     hawaiian_m         1
# 1         2 2023-01-01 11:53:26                 2     big_meat_l         1
# 2         2 2023-01-01 11:53:26                 3  classic_dlx_m         1
# 3         2 2023-01-01 11:53:26                 4  five_cheese_l         1
# 4         2 2023-01-01 11:53:26                 5       potato_m         1
#
#    pizza_name size  unit_price  total_price category  \
# 0     하와이안 피자    M       21800        21800      스페셜
# 1     빅 미트 피자    L       34000        34000      클래식
# 2  클래식 디럭스 피자    M       20300        20300      클래식
# 3   파이브 치즈 피자    L       31000        31000    베지테리언
# 4     포테이토 피자    M       21800        21800      스페셜
#
#                                    ingredients  month  day  hour type_of_day  \
# 0                      토마토, 베이컨, 파인애플, 모짜렐라 치즈      1    6    11          휴일
# 1                     베이컨, 토마토, 페퍼로니, 살라미, 초리조      1    6    11          휴일
# 2                  토마토, 페퍼로니, 버섯, 적양파, 피망, 베이컨      1    6    11          휴일
# 3  모짜렐라 치즈, 프로볼로네 치즈, 고다 치즈, 페코리노 치즈, 고르곤졸라 치즈      1    6    11          휴일
# 4         모짜렐라 치즈, 토마토, 감자, 양파, 베이컨, 옥수수, 마요네즈      1    6    11          휴일
#
#                              ingredients_handled
# 0                      [토마토, 베이컨, 파인애플, 모짜렐라 치즈]
# 1                     [베이컨, 토마토, 페퍼로니, 살라미, 초리조]
# 2                  [토마토, 페퍼로니, 버섯, 적양파, 피망, 베이컨]
# 3  [모짜렐라 치즈, 프로볼로네 치즈, 고다 치즈, 페코리노 치즈, 고르곤졸라 치즈]
# 4         [모짜렐라 치즈, 토마토, 감자, 양파, 베이컨, 옥수수, 마요네즈]

# %%
pizza_orders_df = pizza_orders_df.explode('ingredients_handled')
pizza_orders_df.head()
# Out:
#    order_id     order_timestamp  order_details_id    pizza_id  quantity  \
# 0         1 2023-01-01 11:45:11                 1  hawaiian_m         1
# 0         1 2023-01-01 11:45:11                 1  hawaiian_m         1
# 0         1 2023-01-01 11:45:11                 1  hawaiian_m         1
# 0         1 2023-01-01 11:45:11                 1  hawaiian_m         1
# 1         2 2023-01-01 11:53:26                 2  big_meat_l         1
#
#   pizza_name size  unit_price  total_price category               ingredients  \
# 0    하와이안 피자    M       21800        21800      스페셜   토마토, 베이컨, 파인애플, 모짜렐라 치즈
# 0    하와이안 피자    M       21800        21800      스페셜   토마토, 베이컨, 파인애플, 모짜렐라 치즈
# 0    하와이안 피자    M       21800        21800      스페셜   토마토, 베이컨, 파인애플, 모짜렐라 치즈
# 0    하와이안 피자    M       21800        21800      스페셜   토마토, 베이컨, 파인애플, 모짜렐라 치즈
# 1    빅 미트 피자    L       34000        34000      클래식  베이컨, 토마토, 페퍼로니, 살라미, 초리조
#
#    month  day  hour type_of_day ingredients_handled
# 0      1    6    11          휴일                 토마토
# 0      1    6    11          휴일                 베이컨
# 0      1    6    11          휴일                파인애플
# 0      1    6    11          휴일             모짜렐라 치즈
# 1      1    6    11          휴일                 베이컨

# %%
size_weights = {'S': 1, 'M': 2, 'L': 3}
pizza_orders_df['weighted_quantity'] = pizza_orders_df.apply(
    lambda row: row['quantity'] * size_weights[row['size']], axis=1
)
pizza_orders_df.head()
# Out:
#    order_id     order_timestamp  order_details_id    pizza_id  quantity  \
# 0         1 2023-01-01 11:45:11                 1  hawaiian_m         1
# 0         1 2023-01-01 11:45:11                 1  hawaiian_m         1
# 0         1 2023-01-01 11:45:11                 1  hawaiian_m         1
# 0         1 2023-01-01 11:45:11                 1  hawaiian_m         1
# 1         2 2023-01-01 11:53:26                 2  big_meat_l         1
#
#   pizza_name size  unit_price  total_price category               ingredients  \
# 0    하와이안 피자    M       21800        21800      스페셜   토마토, 베이컨, 파인애플, 모짜렐라 치즈
# 0    하와이안 피자    M       21800        21800      스페셜   토마토, 베이컨, 파인애플, 모짜렐라 치즈
# 0    하와이안 피자    M       21800        21800      스페셜   토마토, 베이컨, 파인애플, 모짜렐라 치즈
# 0    하와이안 피자    M       21800        21800      스페셜   토마토, 베이컨, 파인애플, 모짜렐라 치즈
# 1    빅 미트 피자    L       34000        34000      클래식  베이컨, 토마토, 페퍼로니, 살라미, 초리조
#
#    month  day  hour type_of_day ingredients_handled  weighted_quantity
# 0      1    6    11          휴일                 토마토                  2
# 0      1    6    11          휴일                 베이컨                  2
# 0      1    6    11          휴일                파인애플                  2
# 0      1    6    11          휴일             모짜렐라 치즈                  2
# 1      1    6    11          휴일                 베이컨                  3

# %%
ingredient_usage = pizza_orders_df.groupby('ingredients_handled')['weighted_quantity'].sum().reset_index()
ingredient_usage_sorted = ingredient_usage.sort_values('weighted_quantity', ascending=False)
ingredient_usage_sorted
# Out:
#    ingredients_handled  weighted_quantity
# 25                 토마토              88428
# 8              모짜렐라 치즈              49393
# 32                  피망              40181
# 11                 베이컨              36562
# 29                페퍼로니              36402
# 26                파인애플              25535
# 20                 적양파              25481
# 23                  치킨              21222
# 6                   마늘              17506
# 19                 옥수수              14252
# 10                  버섯              13962
# 24            타이 칠리 소스              12281
# 18                  양파              11674
# 17                아티초크              10402
# 27              페스토 소스              10402
# 28             페코리노 치즈               8979
# 2                고다 치즈               8979
# 3             고르곤졸라 치즈               8979
# 30            프로볼로네 치즈               8979
# 9               바비큐 소스               8941
# 1                   감자               7148
# 7                 마요네즈               7148
# 4               그린 올리브               7104
# 14                 살라미               6724
# 22                 초리조               6724
# 16            썬드라이 토마토               5405
# 15                 시금치               5405
# 21                 쥬키니               4997
# 0                   가지               4997
# 13              불고기 소스               4526
# 12                 불고기               4526
# 5                  루꼴라               2348
# 31                프로슈토               2348

# %%
used_pizzas = pizza_orders_df.groupby('ingredients_handled')['pizza_name'].unique().reset_index()
used_pizzas
# Out:
#    ingredients_handled                                         pizza_name
# 0                   가지                                         [그린 가든 피자]
# 1                   감자                                          [포테이토 피자]
# 2                고다 치즈                                        [파이브 치즈 피자]
# 3             고르곤졸라 치즈                                        [파이브 치즈 피자]
# 4               그린 올리브                                        [슈퍼 슈프림 피자]
# 5                  루꼴라                                      [프로슈토 루꼴라 피자]
# 6                   마늘                  [슈퍼 슈프림 피자, 그린 가든 피자, 시금치 페스토 피자]
# 7                 마요네즈                                          [포테이토 피자]
# 8              모짜렐라 치즈  [하와이안 피자, 파이브 치즈 피자, 포테이토 피자, 페퍼로니 피자, 프로슈토 루꼴...
# 9               바비큐 소스                                        [바비큐 치킨 피자]
# 10                  버섯                               [클래식 디럭스 피자, 불고기 피자]
# 11                 베이컨            [하와이안 피자, 빅 미트 피자, 클래식 디럭스 피자, 포테이토 피자]
# 12                 불고기                                           [불고기 피자]
# 13              불고기 소스                                           [불고기 피자]
# 14                 살라미                                          [빅 미트 피자]
# 15                 시금치                                       [시금치 페스토 피자]
# 16            썬드라이 토마토                                       [시금치 페스토 피자]
# 17                아티초크                             [그린 가든 피자, 시금치 페스토 피자]
# 18                  양파                                  [포테이토 피자, 불고기 피자]
# 19                 옥수수                               [포테이토 피자, 슈퍼 슈프림 피자]
# 20                 적양파                 [클래식 디럭스 피자, 슈퍼 슈프림 피자, 바비큐 치킨 피자]
# 21                 쥬키니                                         [그린 가든 피자]
# 22                 초리조                                          [빅 미트 피자]
# 23                  치킨                              [타이 치킨 피자, 바비큐 치킨 피자]
# 24            타이 칠리 소스                                         [타이 치킨 피자]
# 25                 토마토  [하와이안 피자, 빅 미트 피자, 클래식 디럭스 피자, 포테이토 피자, 타이 치킨 ...
# 26                파인애플                                [하와이안 피자, 타이 치킨 피자]
# 27              페스토 소스                             [그린 가든 피자, 시금치 페스토 피자]
# 28             페코리노 치즈                                        [파이브 치즈 피자]
# 29                페퍼로니          [빅 미트 피자, 클래식 디럭스 피자, 페퍼로니 피자, 슈퍼 슈프림 피자]
# 30            프로볼로네 치즈                                        [파이브 치즈 피자]
# 31                프로슈토                                      [프로슈토 루꼴라 피자]
# 32                  피망  [클래식 디럭스 피자, 타이 치킨 피자, 바비큐 치킨 피자, 그린 가든 피자, 불고...

# %%
ingredient_usage_and_pizzas = pd.merge(ingredient_usage_sorted, used_pizzas, how='left', on='ingredients_handled')
ingredient_usage_and_pizzas
# Out:
#    ingredients_handled  weighted_quantity  \
# 0                  토마토              88428
# 1              모짜렐라 치즈              49393
# 2                   피망              40181
# 3                  베이컨              36562
# 4                 페퍼로니              36402
# 5                 파인애플              25535
# 6                  적양파              25481
# 7                   치킨              21222
# 8                   마늘              17506
# 9                  옥수수              14252
# 10                  버섯              13962
# 11            타이 칠리 소스              12281
# 12                  양파              11674
# 13                아티초크              10402
# 14              페스토 소스              10402
# 15             페코리노 치즈               8979
# 16               고다 치즈               8979
# 17            고르곤졸라 치즈               8979
# 18            프로볼로네 치즈               8979
# 19              바비큐 소스               8941
# 20                  감자               7148
# 21                마요네즈               7148
# 22              그린 올리브               7104
# 23                 살라미               6724
# 24                 초리조               6724
# 25            썬드라이 토마토               5405
# 26                 시금치               5405
# 27                 쥬키니               4997
# 28                  가지               4997
# 29              불고기 소스               4526
# 30                 불고기               4526
# 31                 루꼴라               2348
# 32                프로슈토               2348
#
#                                            pizza_name
# 0   [하와이안 피자, 빅 미트 피자, 클래식 디럭스 피자, 포테이토 피자, 타이 치킨 ...
# 1   [하와이안 피자, 파이브 치즈 피자, 포테이토 피자, 페퍼로니 피자, 프로슈토 루꼴...
# 2   [클래식 디럭스 피자, 타이 치킨 피자, 바비큐 치킨 피자, 그린 가든 피자, 불고...
# 3             [하와이안 피자, 빅 미트 피자, 클래식 디럭스 피자, 포테이토 피자]
# 4           [빅 미트 피자, 클래식 디럭스 피자, 페퍼로니 피자, 슈퍼 슈프림 피자]
# 5                                 [하와이안 피자, 타이 치킨 피자]
# 6                  [클래식 디럭스 피자, 슈퍼 슈프림 피자, 바비큐 치킨 피자]
# 7                               [타이 치킨 피자, 바비큐 치킨 피자]
# 8                   [슈퍼 슈프림 피자, 그린 가든 피자, 시금치 페스토 피자]
# 9                                [포테이토 피자, 슈퍼 슈프림 피자]
# 10                               [클래식 디럭스 피자, 불고기 피자]
# 11                                         [타이 치킨 피자]
# 12                                  [포테이토 피자, 불고기 피자]
# 13                             [그린 가든 피자, 시금치 페스토 피자]
# 14                             [그린 가든 피자, 시금치 페스토 피자]
# 15                                        [파이브 치즈 피자]
# 16                                        [파이브 치즈 피자]
# 17                                        [파이브 치즈 피자]
# 18                                        [파이브 치즈 피자]
# 19                                        [바비큐 치킨 피자]
# 20                                          [포테이토 피자]
# 21                                          [포테이토 피자]
# 22                                        [슈퍼 슈프림 피자]
# 23                                          [빅 미트 피자]
# 24                                          [빅 미트 피자]
# 25                                       [시금치 페스토 피자]
# 26                                       [시금치 페스토 피자]
# 27                                         [그린 가든 피자]
# 28                                         [그린 가든 피자]
# 29                                           [불고기 피자]
# 30                                           [불고기 피자]
# 31                                      [프로슈토 루꼴라 피자]
# 32                                      [프로슈토 루꼴라 피자]

# %%
plt.rcParams['figure.figsize'] = (10, 6)
sns.barplot(data=ingredient_usage_sorted, x='weighted_quantity', y='ingredients_handled')
plt.title('재료 사용량')
plt.xlabel('사용량')
plt.ylabel('재료')
plt.show()
